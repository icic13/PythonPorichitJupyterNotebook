# %%
pwd
# Out:
# u'/home/rana/PythonPorichitJupyterNotebook'

# %%
mkdir python

# %%
cd python/
# Out:
# /home/rana/PythonPorichitJupyterNotebook/python

# %%
pwd
# Out:
# u'/home/rana/PythonPorichitJupyterNotebook/python'

# %%
# %%writefile hello.py
print "Hello World"
# Out:
# Writing hello.py

# %%
ls
# Out:
# hello.py

# %%
run hello.py
# Out:
# Hello World

# %%
cd ..
# Out:
# /home/rana/PythonPorichitJupyterNotebook

# %%
cd hello.py
# Out:
# [Errno 2] No such file or directory: 'hello.py'
# /home/rana/PythonPorichitJupyterNotebook

# %%
cd python/
# Out:
# /home/rana/PythonPorichitJupyterNotebook/python

# %%
# %%writefile add.py
a = 10
b = 5
print a + b
# Out:
# Writing add.py

# %%
ls
# Out:
# add.py  hello.py

# %%
run add.py
# Out:
# 15

# %%
# %%writefile add.py
a = raw_input()
b = raw_input()
print a + b
# Out:
# Overwriting add.py

# %%
run add.py
# Out:
# 5
# 2
# 52

# %%
# %%writefile add.py
a = int(raw_input())
b = int(raw_input())
print a + b
# Out:
# Overwriting add.py

# %%
run add.py
# Out:
# 6
# 8
# 14

# %%
x = input()
# Out:
# 99

# %%
x
# Out:
# 99

# %%
type(x)
# Out:
# int

# %% [markdown]
# # প্যাকেজ

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_21',
#  '_22',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__name__',
#  '__nonzero__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x']

# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BufferError',
#  'BytesWarning',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'NameError',
#  'None',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'ReferenceError',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StandardError',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__IPYTHON__active',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__name__',
#  '__package__',
#  'abs',
#  'all',
#  'any',
#  'apply',
#  'basestring',
#  'bin',
#  'bool',
#  'buffer',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'cmp',
#  'coerce',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'divmod',
#  'dreload',
#  'enumerate',
#  'eval',
#  'execfile',
#  'file',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'intern',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'long',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'raw_input',
#  'reduce',
#  'reload',
#  'repr',
#  'reversed',
#  'round',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'unichr',
#  'unicode',
#  'vars',
#  'xrange',
#  'zip']

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5262b4798965> in <module>()
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5262b4798965> in <module>()
# ----> 1 sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
from math import sqrt

# %%
sqrt(25)
# Out:
# 5.0

# %%
from math import *

# %% [markdown]
# # ফাংশন তৈরির পদ্ধতি

# %%
def function_name(parameters):
    '''code'''
    '''code'''
    return

# %%
 def add(n1, n2):
        return n1 + n2

# %%
# %%writefile add.py
def add(n1, n2):
return sum
v = add(5,6)
print v
# Out:
# Overwriting add.py

# %%
run add.py
# Out:
#   File "/home/rana/PythonPorichitJupyterNotebook/python/add.py", line 2
#     return sum
#          ^
# IndentationError: expected an indented block

# %%
# %%writefile add.py
def add(n1,n2):
    sum = n1 + n2
    return sum
v = add(5,6)
print v
# Out:
# Overwriting add.py

# %%
run add.py
# Out:
# 11

# %% [markdown]
# # ফাংশনে প্যারামিটার পাঠানো

# %%
a = [1, 2, 3]

# %%
b = a

# %%
b.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b = [1,2,3,4]
a = [1,2,3,4]

# %%
def fnc(x,li):
    x = 1000
    li.append(x)
    return x

# %%
# Out:
# list before function call:  [1, 2, 3]
# type of x:  <type 'int'>
# type of li:  <type 'list'>
# value of y: 500
# value of a 10
# list after function call:  [1, 2, 3, 4]

# %%
# %%writefile test.py
def fnc(x,li):
    print 'type of x: ',type(x)
    print 'type of li: ',type(li)
    
    x = 500
    li.append(4)
    return x
a = 10
my_li = [1,2,3]
print 'list before function call: ',my_li
y = fnc(a,my_li)
print 'value of y:',y
print 'value of a',a
print 'list after function call: ',my_li
# Out:
# Writing test.py

# %%
run test.py
# Out:
# list before function call:  [1, 2, 3]
# type of x:  <type 'int'>
# type of li:  <type 'list'>
# value of y: 500
# value of a 10
# list after function call:  [1, 2, 3, 4]

# %% [markdown]
# # ফাংশনে ডিফল্ট প্যারামিটার

# %%
def fnc(x, y, z = 0):
    print x, y, z

# %%
fnc(10,20)
# Out:
# 10 20 0

# %%
fnc(10,20,30)
# Out:
# 10 20 30

# %%
z = None

# %%
if z is None:
    z = []

# %% [markdown]
# # ফংশন থেকে একাধিক জিনিস রিটার্ন করা

# %%
def fnc(x,y,z = 0):
    print x, y, z
    return x, y, z

# %%
# %%writefile test.py
def fnc(x, y , z = 0):
    x = x * x
    y = y * y
    z = z * z
    return x, y, z
print fnc(10, 20, 30)
x,y,z = fnc(10,20,30)
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 900)
# 100
# 400
# 900

# %%
# %%writefile test.py
def fnc(x, y , z = 0):
    x = x * x
    y = y * y
    z = z * z
    return x, y, z
print fnc(10, 20, 30)
x,y,z = fnc(10,20)
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 900)
# 100
# 400
# 0

# %%
# %%writefile test.py
def fnc(x, y , z = 0):
    x = x * x
    y = y * y
    z = z * z
    return x, y, z
print fnc(10, 20, 30)
x,y,z = fnc(10,20,z = '100')
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 900)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in <module>()
#       5     return x, y, z
#       6 print fnc(10, 20, 30)
# ----> 7 x,y,z = fnc(10,20,z = '100')
#       8 print x
#       9 print y
#
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in fnc(x, y, z)
#       2     x = x * x
#       3     y = y * y
# ----> 4     z = z * z
#       5     return x, y, z
#       6 print fnc(10, 20, 30)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# %%writefile test.py
def fnc(x, y , z = 1):
    x = x * x
    y = y * y
    z = z * z
    return x, y, z
print fnc(10, 20, 30)
x,y,z = fnc(10,20)
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 900)
# 100
# 400
# 1

# %%
# %%writefile test.py
def fnc(x, y , z = None):
    x = x * x
    y = y * y
    z = z * z
    return x, y, z
print fnc(10, 20, 30)
x,y,z = fnc(10,20)
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 900)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in <module>()
#       5     return x, y, z
#       6 print fnc(10, 20, 30)
# ----> 7 x,y,z = fnc(10,20)
#       8 print x
#       9 print y
#
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in fnc(x, y, z)
#       2     x = x * x
#       3     y = y * y
# ----> 4     z = z * z
#       5     return x, y, z
#       6 print fnc(10, 20, 30)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
# %%writefile test.py
def fnc(x, y , z = None):
    x = x * x
    y = y * y
    if z is None:
        z = []
    return x, y, z
print fnc(10, 20)
x,y,z = fnc(10,20)
print x
print y
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# (100, 400, 30)
# 100
# 400
# []

# %%
def fnc(x, y , z = 0):
    x = x * x
    y = y * y
    z = z * z
    return (x, y, z)

# %% [markdown]
# # মডিউল

# %%
 # %%writefile ops.py
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return a/b
# Out:
# Overwriting ops.py

# %%
import ops

# %%
# %%writefile test.py
x = 10
y = 5
z = add(x,y)
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in <module>()
#       1 x = 10
#       2 y = 5
# ----> 3 z = add(x,y)
#       4 print z
#
# NameError: name 'add' is not defined

# %%
# %%writefile test.py
import ops
x = 10
y = 5
z = add(x,y)
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rana/PythonPorichitJupyterNotebook/python/test.py in <module>()
#       2 x = 10
#       3 y = 5
# ----> 4 z = add(x,y)
#       5 print z
#
# NameError: name 'add' is not defined

# %%
# %%writefile test.py
import ops
x = 10
y = 5
z = ops.add(x,y)
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# 15

# %%
# %%writefile test.py
import ops
x = 10
y = 5
z = ops.mul(x,y)
print z
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# 50

# %%
# %%writefile ops.py
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return a/b
PI = 3.1415926
# Out:
# Writing ops.py

# %%
cat ops.py
# Out:
# def add(a,b):
#     return a+b
# def sub(a,b):
#     return a-b
# def mul(a,b):
#     return a*b
# def div(a,b):
#     return a/b
# PI = 3.1415926

# %%
import ops

# %%
ops.PI
# Out:
# 3.1415926

# %%
# %%writefile test.py
import ops
x = 10
y = 5
z = ops.add(x,y)
print z
print ops.PI
# Out:
# Writing test.py

# %%
run test.py
# Out:
# 15
# 3.1415926

# %%
# %%writefile test.py
import ops
x = 10
y = 5
z = ops.add(x,y)
print z
print PI
# Out:
# Overwriting test.py

# %%
run test.py
# Out:
# 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rana/PythonPorichitJupyterNotebook/test.py in <module>()
#       4 z = ops.add(x,y)
#       5 print z
# ----> 6 print PI
#
# NameError: name 'PI' is not defined

# %% [markdown]
# # প্যাকেজ

# %%
mkdir my_math

# %%
ls
# Out:
# my_math/  test.py                      পাইথনে স্ট্রিং-এর ব্যবহার .ipynb
# ops.py    কন্ডিশনাল লজিক.ipynb          পাইথনে হাতেখড়ি .ipynb
# ops.pyc   পাইথনের ডাটা স্ট্রাকচার.ipynb  ফাংশন ও মডিউল.ipynb
# python/   পাইথনের লুপ.ipynb             লিস্টের সঙ্গে পরিচয়.ipynb

# %%
cd my_math/
# Out:
# /home/rana/PythonPorichitJupyterNotebook/my_math

# %%
# %%writefile __init__.py
''
# Out:
# Writing __init__.py

# %%
mkdir arith geo

# %%
ls
# Out:
# arith/  geo/  __init__.py

# %%
# %%writefile arith/__init__.py 
''
# Out:
# Writing arith/__init__.py

# %%
# %%writefile geo/__init__.py
''
# Out:
# Writing geo/__init__.py

# %%
ls
# Out:
# arith/  geo/  __init__.py

# %%
# %%writefile arith/ops.py
''
# Out:
# Writing arith/ops.py

# %%
# %%writefile geo/circle.py
''
# Out:
# Writing geo/circle.py

# %%
# %%writefile geo/square.py
''
# Out:
# Writing geo/square.py

# %%
cd ..
# Out:
# /home/rana/PythonPorichitJupyterNotebook

# %%
pwd
# Out:
# u'/home/rana/PythonPorichitJupyterNotebook'

# %%
ls
# Out:
# my_math/  test.py                      পাইথনে স্ট্রিং-এর ব্যবহার .ipynb
# ops.py    কন্ডিশনাল লজিক.ipynb          পাইথনে হাতেখড়ি .ipynb
# ops.pyc   পাইথনের ডাটা স্ট্রাকচার.ipynb  ফাংশন ও মডিউল.ipynb
# python/   পাইথনের লুপ.ipynb             লিস্টের সঙ্গে পরিচয়.ipynb

# %%
import my_math.geo

# %%
# %%writefile my_math/arith/ops.py
def add(x,y):
    return x + y
def sub(x,y):
    return x - y
# Out:
# Overwriting my_math/arith/ops.py

# %%
# %%writefile my_math/geo/square.py
def area(x):
    return x*x
def perimeter(x):
    return x*4
# Out:
# Overwriting my_math/geo/square.py

# %%
import my_math.arith.ops

# %%
my_math.arith.ops.add(3,5)
# Out:
# 8

# %%
import my_math.arith.ops as my_ops

# %%
my_ops.sub(5,1)
# Out:
# 4

# %%
my_ops.add(8,9)
# Out:
# 17

# %%
from my_math.geo.square import area

# %%
area(2)
# Out:
# 4

# %%
cd ..
# Out:
# /home/rana

# %%
from my_math.geo.square import area

# %%
area(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd0ebd5d5d2f> in <module>()
# ----> 1 area(2)
#
# NameError: name 'area' is not defined

# %%
import sys

# %%
sys.path
# Out:
# ['',
#  '/home/rana/anaconda2/lib/python27.zip',
#  '/home/rana/anaconda2/lib/python2.7',
#  '/home/rana/anaconda2/lib/python2.7/plat-linux2',
#  '/home/rana/anaconda2/lib/python2.7/lib-tk',
#  '/home/rana/anaconda2/lib/python2.7/lib-old',
#  '/home/rana/anaconda2/lib/python2.7/lib-dynload',
#  '/home/rana/anaconda2/lib/python2.7/site-packages/Sphinx-1.3.1-py2.7.egg',
#  '/home/rana/anaconda2/lib/python2.7/site-packages/setuptools-18.4-py2.7.egg',
#  '/home/rana/anaconda2/lib/python2.7/site-packages',
#  '/home/rana/anaconda2/lib/python2.7/site-packages/cryptography-1.0.2-py2.7-linux-x86_64.egg',
#  '/home/rana/anaconda2/lib/python2.7/site-packages/IPython/extensions',
#  '/home/rana/.ipython']
